# %% [markdown]
# <a href="https://colab.research.google.com/github/martinsadw/alura/blob/main/Pandas%20IO%20-%20trabalhando%20com%20diferentes%20formatos%20de%20arquivos/Superstore_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data.csv
# Out:
# --2024-04-17 12:14:10--  https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181941 (178K) [text/plain]
# Saving to: ‘superstore_data.csv’
#
# superstore_data.csv 100%[===================>] 177.68K  --.-KB/s    in 0.03s
#
# 2024-04-17 12:14:11 (6.87 MB/s) - ‘superstore_data.csv’ saved [181941/181941]

# %% [markdown]
# # 1. Importing

# %%
import pandas as pd

# %%
store = pd.read_csv('superstore_data.csv', parse_dates=['Dt_Customer'], index_col='Id')
store
# Out:
#        Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# Id
# 1826         1970  Graduation       Divorced  84835.0        0         0
# 1            1961  Graduation         Single  57091.0        0         0
# 10476        1958  Graduation        Married  67267.0        0         1
# 1386         1967  Graduation       Together  32474.0        1         1
# 5371         1989  Graduation         Single  21474.0        1         0
# ...           ...         ...            ...      ...      ...       ...
# 10142        1976         PhD       Divorced  66476.0        0         1
# 5263         1977    2n Cycle        Married  31056.0        1         0
# 22           1976  Graduation       Divorced  46310.0        1         0
# 528          1978  Graduation        Married  65819.0        0         0
# 4070         1969         PhD        Married  94871.0        0         2
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  MntFishProducts  \
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
store.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...
