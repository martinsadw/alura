# %% [markdown]
# <a href="https://colab.research.google.com/github/martinsadw/alura/blob/main/Pandas%20-%20transforma%C3%A7%C3%A3o%20e%20manipula%C3%A7%C3%A3o%20de%20dados/sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Description

# %% [markdown]
# O objetivo desse projeto é realizar uma análise dos resultados de um evento com os clientes de uma empresa de vendas online. Foi coletado um conjunto de dados que contém os clientes que mais gastaram com produtos dentro de 5 dias de vendas, que é o período de duração do evento. Essa análise vai identificar o cliente com a maior compra na semana, que irá receber um prêmio da loja, e posteriormente, ela pode ajudar a empresa a criar novas estratégias para atrair mais clientes.
#
# A base de dados utilizada nessa análise é a [dados_vendas_clientes.json](https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_vendas_clientes.json) e contém informações importantes sobre os clientes como, o nome de cadastro do cliente, o valor total pago na compra e o dia da compra.

# %%
# !wget https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_vendas_clientes.json
# Out:
# --2024-05-05 11:14:50--  https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_vendas_clientes.json
# Resolving cdn3.gnarususercontent.com.br (cdn3.gnarususercontent.com.br)... 172.67.75.65, 104.26.14.179, 104.26.15.179, ...
# Connecting to cdn3.gnarususercontent.com.br (cdn3.gnarususercontent.com.br)|172.67.75.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1032 (1.0K) [application/json]
# Saving to: ‘dados_vendas_clientes.json’
#
# dados_vendas_client 100%[===================>]   1.01K  --.-KB/s    in 0s
#
# 2024-05-05 11:14:51 (8.64 MB/s) - ‘dados_vendas_clientes.json’ saved [1032/1032]

# %%
import pandas as pd

# %%
import json
from pprint import pprint
with open('dados_vendas_clientes.json', 'r') as file:
    sales_json = json.load(file)

# %%
print(sales_json.keys())
pprint(sales_json['dados_vendas'][0])
# Out:
# dict_keys(['dados_vendas'])
# {'Cliente': ['@ANA _LUCIA 321',
#              'DieGO ARMANDIU 210',
#              'DieGO ARMANDIU 210',
#              'DieGO ARMANDIU 210'],
#  'Data de venda': '06/06/2022',
#  'Valor da compra': ['R$ 836,5', 'R$ 573,33', 'R$ 392,8', 'R$ 512,34']}

# %% [markdown]
# # 1. Importing

# %%
sales = pd.json_normalize(sales_json['dados_vendas'])
sales
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
explode_columns = ['Cliente', 'Valor da compra']
exploded_sales = sales.explode(explode_columns).reset_index(drop=True)
exploded_sales.head()
# Out:
#   Data de venda             Cliente Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 1    06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 2    06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 3    06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 4    07/06/2022  Isabely JOanes 738       R$ 825,31

# %%
converted_sales = exploded_sales.copy()
converted_sales['Valor da compra'] = exploded_sales['Valor da compra'].str.replace('R$', '').str.replace(',', '.').str.strip().astype(float)
converted_sales.head()
# Out:
#   Data de venda             Cliente  Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321           836.50
# 1    06/06/2022  DieGO ARMANDIU 210           573.33
# 2    06/06/2022  DieGO ARMANDIU 210           392.80
# 3    06/06/2022  DieGO ARMANDIU 210           512.34
# 4    07/06/2022  Isabely JOanes 738           825.31

# %%
converted_sales['Cliente'] = converted_sales['Cliente'].str.replace('[^a-zA-Z ]', '', regex=True).str.lower()
converted_sales.head()
# Out:
#   Data de venda          Cliente  Valor da compra
# 0    06/06/2022       ana lucia            836.50
# 1    06/06/2022  diego armandiu            573.33
# 2    06/06/2022  diego armandiu            392.80
# 3    06/06/2022  diego armandiu            512.34
# 4    07/06/2022  isabely joanes            825.31
